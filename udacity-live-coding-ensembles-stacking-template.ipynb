# %%
# libs basicas data science
from sklearn import datasets
import numpy as np
import pandas as pd
from scipy import stats
import math

#libs visualizacao
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from IPython.display import Image
from IPython.core.display import HTML
from mlxtend.plotting import plot_decision_regions

#sklean model selection http://scikit-learn.org/
from sklearn.model_selection import cross_val_score, train_test_split

#sklearn classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier

# mlxtend classifiers https://rasbt.github.io/mlxtend/
from mlxtend.classifier import StackingClassifier
from mlxtend.classifier import StackingCVClassifier

# %%
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 10)
sns.set(style="ticks")

# %% [markdown]
# # Iris Dataset

# %%
iris = datasets.load_iris()

# %%
iris_df = pd.DataFrame(data= np.c_[iris['data'], iris.target_names[iris.target]], 
                       columns= iris['feature_names'] + ['class'])
for col in iris['feature_names']:
    iris_df[col] = pd.to_numeric(iris_df[col])

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df.groupby('class').size()
# Out:
# class
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(iris_df, hue="class", diag_kind="kde")
plt.show()

# %% [markdown]
# # Métodos utilitários

# %%
def get_predictions(models, X, y):
    validation_size = 0.20
    seed = 13
    X_train, X_validation, y_train, y_validation = \
        train_test_split(X, y, test_size=validation_size, random_state=seed)    
    predictions = [y_validation]
    labels = []
    for name in models.keys():
        model = models[name]
        model.fit(X_train, y_train)
        predictions.append(model.predict(X_validation))
        labels.append(name)
    predictions_df = pd.DataFrame(data=np.transpose(predictions), columns=(['Y'] + list(models.keys()))) 
    return predictions_df

# %%
def models_correlation(predictions_df):
    corr = predictions_df.iloc[:, 1:].corr()
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(corr, annot=True, mask=mask, cmap="YlGnBu")
    plt.show()

# %%
def highlight_error(s):
    is_error = s != s.iloc[0]
    return ['color: red' if v else 'color: black' for v in is_error]

# %%
def print_predictions(models, X, y):
    predictions_df = get_predictions(models, X, y)
    return predictions_df.style.apply(highlight_error, axis=1)

# %%
def train_and_report(models, X, y):
    results = []
    for name in models.keys():
        model = models[name]
        scores = cross_val_score(model, X, y, cv=10, scoring='accuracy')
        print("Accuracy: %.3f (+/- %.3f) [%s]" %(scores.mean(), scores.std(), name))

# %%
def plot_decision_boundaries(models, X, y, cols=3):
        
    fig = plt.figure()
    rows = math.ceil(len(models) / (cols * 1.0))
    gs = gridspec.GridSpec(rows, cols)
    grid = []
    for r in range(rows):
        for c in range(cols):
            grid.append((r,c))

    clf_list = models.values()
    labels = models.keys()
    
    for clf, label, grd in zip(clf_list, labels, grid):
        
        clf.fit(X, y)
        ax = plt.subplot(gs[grd[0], grd[1]])
        fig = plot_decision_regions(X=X, y=y, clf=clf, legend=2)
        plt.title(label)

    plt.show()

# %% [markdown]
# # Treinamento dos modelos isoladamente

# %%
X, y = iris.data[:, 0:2], iris.target

# %%
models = {}
models['LR'] = LogisticRegression()
models['LDA'] = LinearDiscriminantAnalysis()
models['KNN'] = KNeighborsClassifier()
models['CART'] = DecisionTreeClassifier(random_state=13)
models['NB'] = GaussianNB()
models['SVC'] = SVC(probability=True)

# %%
train_and_report(models, X, y)
# Out:
# Accuracy: 0.760 (+/- 0.074) [LR]
# Accuracy: 0.793 (+/- 0.096) [LDA]
# Accuracy: 0.747 (+/- 0.083) [KNN]
# Accuracy: 0.667 (+/- 0.094) [CART]
# Accuracy: 0.793 (+/- 0.087) [NB]
# Accuracy: 0.813 (+/- 0.078) [SVC]

# %%
plot_decision_boundaries(models, X, y)

# %% [markdown]
# # Votação

# %% [markdown]
# ## Maioria

# %%
voting_models_names = models.keys()
#voting_models_names = ['LR', 'KNN', 'LDA']
voting_models = {name: models[name] for name in voting_models_names}
voting_estimators = [(name, models[name]) for name in voting_models_names]

# %%
print_predictions(voting_models, X, y)
# Out:
# <style  type="text/css" >
#     #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow0_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow1_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow2_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col1 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col2 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col3 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col4 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col5 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow3_col6 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col3 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col4 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow4_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow5_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow6_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col1 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col2 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col5 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow7_col6 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow8_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col5 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow9_col6 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col1 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col2 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col3 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col4 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col5 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow10_col6 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col1 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col2 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col3 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col4 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col5 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow11_col6 {
#             color:  red;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow12_col0 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow12_col1 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow12_col2 {
#             color:  black;
#         }    #T_35c2c9a8_b380_11e7_a15f_28565ae9deddrow12_col3 {
#             color:  black;

# %%
voting_models['MAJORITY'] = VotingClassifier(estimators=voting_estimators, voting='hard')

# %%
train_and_report(voting_models, X, y)
# Out:
# Accuracy: 0.760 (+/- 0.074) [LR]
# Accuracy: 0.793 (+/- 0.096) [LDA]
# Accuracy: 0.747 (+/- 0.083) [KNN]
# Accuracy: 0.667 (+/- 0.094) [CART]
# Accuracy: 0.793 (+/- 0.087) [NB]
# Accuracy: 0.813 (+/- 0.078) [SVC]
# Accuracy: 0.820 (+/- 0.085) [MAJORITY]

# %%
plot_decision_boundaries(voting_models, X, y)

# %%
print_predictions(voting_models, X, y)
# Out:
# <style  type="text/css" >
#     #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow0_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow1_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow2_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col1 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col2 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col3 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col4 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col5 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col6 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow3_col7 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col3 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col4 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow4_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow5_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow6_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col1 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col2 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col5 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col6 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow7_col7 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow8_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col1 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col2 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col3 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col4 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col5 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col6 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow9_col7 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col0 {
#             color:  black;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col1 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col2 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col3 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col4 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col5 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col6 {
#             color:  red;
#         }    #T_37098086_b380_11e7_a15f_28565ae9deddrow10_col7 {
#             color:  red;
#         }

# %% [markdown]
# ## Ponderado

# %%
voting_models['WEIGHT_AVG'] = VotingClassifier(estimators=voting_estimators,
                                                        #weights=[0.7,0.7,1.0],
                                                        voting='soft')

# %%
train_and_report(voting_models, X, y)
# Out:
# Accuracy: 0.760 (+/- 0.074) [LR]
# Accuracy: 0.793 (+/- 0.096) [LDA]
# Accuracy: 0.747 (+/- 0.083) [KNN]
# Accuracy: 0.667 (+/- 0.094) [CART]
# Accuracy: 0.793 (+/- 0.087) [NB]
# Accuracy: 0.813 (+/- 0.078) [SVC]
# Accuracy: 0.820 (+/- 0.085) [MAJORITY]
# Accuracy: 0.767 (+/- 0.100) [WEIGHT_AVG]

# %%
print_predictions(voting_models, X, y)
# Out:
# <style  type="text/css" >
#     #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow0_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow1_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow2_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col1 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col2 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col3 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col4 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col5 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col6 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col7 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow3_col8 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col3 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col4 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow4_col8 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow5_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow6_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col1 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col2 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col5 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col6 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col7 {
#             color:  red;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow7_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col6 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col7 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow8_col8 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col0 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col1 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col2 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col3 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col4 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col5 {
#             color:  black;
#         }    #T_37098087_b380_11e7_a15f_28565ae9deddrow9_col6 {
#             color:  black;

# %%
plot_decision_boundaries(voting_models, X, y)

# %% [markdown]
# ## Correlação entre os modelos

# %%
predictions = get_predictions(models, X, y)
models_correlation(predictions)

# %% [markdown]
# # Stacking

# %%
Image(url= "https://rasbt.github.io/mlxtend/user_guide/classifier/StackingClassifier_files/stackingclassification_overview.png")
# Out:
# <img src="https://rasbt.github.io/mlxtend/user_guide/classifier/StackingClassifier_files/stackingclassification_overview.png"/>

# %%
stacking_models_names = ['LR', 'KNN', 'CART']
#stacking_models_names = models.keys()
stacking_models = {name: models[name] for name in stacking_models_names}
stacking_models['RF'] = RandomForestClassifier(random_state=13)
stacking_estimators = [models[name] for name in stacking_models_names]
stacking_estimators.append(stacking_models['RF'])

# %%
stacking = StackingClassifier(classifiers=stacking_estimators,
                            use_probas=True,
                            average_probas=True,
                            meta_classifier=models['LR'])

# %%
stacking_models['STACKING'] = stacking

# %%
train_and_report(stacking_models, X, y)
# Out:
# Accuracy: 0.760 (+/- 0.074) [LR]
# Accuracy: 0.747 (+/- 0.083) [KNN]
# Accuracy: 0.667 (+/- 0.094) [CART]
# Accuracy: 0.693 (+/- 0.108) [RF]
# Accuracy: 0.707 (+/- 0.095) [STACKING]

# %%
print_predictions(stacking_models, X, y)
# Out:
# <style  type="text/css" >
#     #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow0_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow1_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow2_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col1 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col2 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col3 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col4 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow3_col5 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col2 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col3 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow4_col5 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow5_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow6_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col1 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow7_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow8_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow9_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col1 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col2 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col3 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col4 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow10_col5 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col1 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow11_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow12_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col1 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col2 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col3 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col4 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow13_col5 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow14_col0 {
#             color:  black;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow14_col1 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow14_col2 {
#             color:  red;
#         }    #T_8d93723a_b381_11e7_a15f_28565ae9deddrow14_col3 {

# %%
plot_decision_boundaries(stacking_models, X, y)
